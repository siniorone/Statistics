# %%
import pandas as pd

# %%
mydict = {
"name": ["sina", "mohammad", "mohammad", "sina"],
"gender": ["M", "M", "M", "M"],
"asd": ["M", "M", "M", "M"],
"dsd": ["M", "M", "M", "M"],
"dddd": ["M", "M", "M", "M"],
    
}

# %%
pd.DataFrame(mydict, 
             index=["A", "B", "C", "D"],
             columns=["name", "gender"])
# Out:
#        name gender
# A      sina      M
# B  mohammad      M
# C  mohammad      M
# D      sina      M

# %%
import numpy as np

# %%
m3 = np.array(
   [[1, 2, 3],
    [10, 20, 30],
    [100, 200, 300]]
)
m3
# Out:
# array([[  1,   2,   3],
#        [ 10,  20,  30],
#        [100, 200, 300]])

# %%
pd.DataFrame(m3,
             columns=["A", "B", "C"],
             index=["X", "Y", "Z"])
# Out:
#      A    B    C
# X    1    2    3
# Y   10   20   30
# Z  100  200  300

# %%
class Car:
    def __init__(self, name, color):
        self.name = name
        self.color = color

# %%
pride = Car("131", "Whtie")

# %%
pride.name
# Out:
# '131'

# %%
pride.__dict__["name"]
# Out:
# '131'

# %%
heart = pd.read_csv("heart.csv")
heart
# Out:
#       Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0    40.0   M           ATA        140          289          0     Normal
# 1     NaN   F           NAP        160          180          0     Normal
# 2    37.0   M           ATA        130          283          0         ST
# 3    48.0   F           ASY        138          214          0     Normal
# 4     NaN   M           NAP        150          195          0     Normal
# ..    ...  ..           ...        ...          ...        ...        ...
# 913  45.0   M            TA        110          264          0     Normal
# 914  68.0   M           ASY        144          193          1     Normal
# 915  57.0   M           ASY        130          131          0     Normal
# 916  57.0   F           ATA        130          236          0        LVH
# 917  38.0   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
heart.shape
# Out:
# (918, 12)

# %%
heart["Age"]
# Out:
# 0      40
# 1      49
# 2      37
# 3      48
# 4      54
#        ..
# 913    45
# 914    68
# 915    57
# 916    57
# 917    38
# Name: Age, Length: 918, dtype: int64

# %%
type(heart["Age"])
# Out:
# pandas.core.series.Series

# %%
heart["RestingECG"]
# Out:
# 0      Normal
# 1      Normal
# 2          ST
# 3      Normal
# 4      Normal
#         ...
# 913    Normal
# 914    Normal
# 915    Normal
# 916       LVH
# 917    Normal
# Name: RestingECG, Length: 918, dtype: object

# %%
pd.Series([1,2,4,5], name="donbale")
# Out:
# 0    1
# 1    2
# 2    4
# 3    5
# Name: donbale, dtype: int64

# %%
myarray = heart.values

# %%
pd.DataFrame(myarray, columns=heart.columns)
# Out:
#     Age Sex ChestPainType RestingBP Cholesterol FastingBS RestingECG MaxHR  \
# 0    40   M           ATA       140         289         0     Normal   172
# 1    49   F           NAP       160         180         0     Normal   156
# 2    37   M           ATA       130         283         0         ST    98
# 3    48   F           ASY       138         214         0     Normal   108
# 4    54   M           NAP       150         195         0     Normal   122
# ..   ..  ..           ...       ...         ...       ...        ...   ...
# 913  45   M            TA       110         264         0     Normal   132
# 914  68   M           ASY       144         193         1     Normal   141
# 915  57   M           ASY       130         131         0     Normal   115
# 916  57   F           ATA       130         236         0        LVH   174
# 917  38   M           NAP       138         175         0     Normal   173
#
#     ExerciseAngina Oldpeak ST_Slope HeartDisease
# ...

# %%
heart.head(2)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1

# %%
heart.iloc[0:2, [1,2]]
# Out:
#   Sex ChestPainType
# 0   M           ATA
# 1   F           NAP

# %%
heart.loc[0:2, "MaxHR":"ST_Slope"]
# Out:
#    MaxHR ExerciseAngina  Oldpeak ST_Slope
# 0    172              N      0.0       Up
# 1    156              N      1.0     Flat
# 2     98              N      0.0       Up

# %%
type(heart.iloc[0])
# Out:
# pandas.core.series.Series

# %%
heart.iloc[-5:]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0

# %%
heart["Age"] == 57
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 913    False
# 914    False
# 915     True
# 916     True
# 917    False
# Name: Age, Length: 918, dtype: bool

# %%
heart.loc[(heart["Age"] == 57) &(heart["HeartDisease"]==0)]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 105   57   M           ATA        140          260          1     Normal
# 199   57   F            TA        130          308          0     Normal
# 278   57   F           ASY        180          347          0         ST
# 539   57   M           ASY        110          197          0        LVH
# 600   57   M           ASY        130          207          0         ST
# 629   57   F           ASY        128          303          0        LVH
# 675   57   M           NAP        150          126          1     Normal
# 686   57   F           ASY        120          354          0     Normal
# 699   57   M           ASY        110          201          0     Normal
# 754   57   M           ASY        132          207          0     Normal
# 837   57   M           NAP        150          168          0     Normal
# 883   57   M           ASY        140          192          0     Normal
#
# ...

# %%
(heart["HeartDisease"]==1)
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 913     True
# 914     True
# 915     True
# 916     True
# 917    False
# Name: HeartDisease, Length: 918, dtype: bool

# %%
(heart["Age"] == 57)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 913    False
# 914    False
# 915     True
# 916     True
# 917    False
# Name: Age, Length: 918, dtype: bool

# %%
(heart["Age"] == 57) | (heart["HeartDisease"]==1)
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 913     True
# 914     True
# 915     True
# 916     True
# 917    False
# Length: 918, dtype: bool

# %%
heart.head(2)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1

# %%
heart.loc[heart["ST_Slope"].isin(["Up", "Down"])]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 4     54   M           NAP        150          195          0     Normal
# 5     39   M           NAP        120          339          0     Normal
# 6     45   F           ATA        130          237          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 906   55   F           ATA        132          342          0     Normal
# 907   44   M           ASY        120          169          0     Normal
# 908   63   M           ASY        140          187          0        LVH
# 910   41   M           ATA        120          157          0     Normal
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
heart["ST_Slope"].isin(["Up", "Down"])
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 913    False
# 914    False
# 915    False
# 916    False
# 917     True
# Name: ST_Slope, Length: 918, dtype: bool

# %%
~(heart["Age"] == 57)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 913     True
# 914     True
# 915    False
# 916    False
# 917     True
# Name: Age, Length: 918, dtype: bool

# %%
heart["Age"]
# Out:
# 0     -41
# 1     -50
# 2     -38
# 3     -49
# 4     -55
#        ..
# 913   -46
# 914   -69
# 915   -58
# 916   -58
# 917   -39
# Name: Age, Length: 918, dtype: int64

# %%
heart.loc[heart["Age"].isnull()]
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 1  NaN   F           NAP        160          180          0     Normal    156
# 4  NaN   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 1              N      1.0     Flat             1
# 4              N      0.0       Up             0

# %%
heart["Age"].isnull()
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 913    False
# 914    False
# 915    False
# 916    False
# 917    False
# Name: Age, Length: 918, dtype: bool

# %%
type(heart.loc[1,"Age"])
# Out:
# numpy.float64

# %%
heart["Age"] = range(0,918)

# %%
heart.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0    0   M           ATA        140          289          0     Normal    172
# 1    1   F           NAP        160          180          0     Normal    156
# 2    2   M           ATA        130          283          0         ST     98
# 3    3   F           ASY        138          214          0     Normal    108
# 4    4   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

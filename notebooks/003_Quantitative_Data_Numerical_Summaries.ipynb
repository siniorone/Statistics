# %% [markdown]
# # Quantitative Data: Numerical Summaries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read data and store it in the Data Frame
scores = pd.read_csv("../data/scores.csv")
# Let's look at the data
print(scores.shape)
scores.head()
# Out:
# (435, 22)
#   School ID                                        School Name    Borough  \
# 0    02M260                 Clinton School Writers and Artists  Manhattan
# 1    06M211  Inwood Early College for Health and Informatio...  Manhattan
# 2    01M539  New Explorations into Science, Technology and ...  Manhattan
# 3    02M294                               Essex Street Academy  Manhattan
# 4    02M308                       Lower Manhattan Arts Academy  Manhattan
#
#   Building Code        Street Address       City State  Zip Code  Latitude  \
# 0          M933  425 West 33rd Street  Manhattan    NY     10001  40.75321
# 1          M052    650 Academy Street  Manhattan    NY     10002  40.86605
# 2          M022   111 Columbia Street  Manhattan    NY     10002  40.71873
# 3          M445      350 Grand Street  Manhattan    NY     10002  40.71687
# 4          M445      350 Grand Street  Manhattan    NY     10002  40.71687
#
# ...

# %%
# Create Histogram of math scores
sns.histplot(data=scores['Average Score (SAT Math)'], kde=True)
# Draw Mean with Red line
plt.axvline(x=scores['Average Score (SAT Math)'].mean(), color='red')
# Draw Mean with Yellow line
plt.axvline(x=scores['Average Score (SAT Math)'].median(), color='yellow')

# %%
# Create Numerical Summaries for math score
scores['Average Score (SAT Math)'].describe().to_frame()
# Out:
#        Average Score (SAT Math)
# count                375.000000
# mean                 432.944000
# std                   71.952373
# min                  317.000000
# 25%                  386.000000
# 50%                  415.000000
# 75%                  458.500000
# max                  754.000000

# %% [markdown]
# ### Interquartile Range:
# $IQR=Q_3 - Q_1 = 458.5 - 385 = 73.5 $

# %% [markdown]
# Because the distribution is skewed to the right, the mean is greater than the median (Q2:**50%**).
#
# The mean is sensitive to extreme observations and the few unusually high scores will tend to bring the mean a bit higher than the median.
#
# Median = 415
#
# Mean = 432.94

# %% [markdown]
# ### Standard Deviation:
#
# SD = 71.95
#
# The standard deviation is roughly the average distance that the values are from the mean.
# We then have a standard deviation of 71.95 meaning that on average
# a  score for this exam was about 71.95 points away from the mean.
